# %%
pip install gspread
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install oauth2client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade google-api-python-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.oauth2.service_account import Credentials
from googleapiclient.discovery import build

# %%
import gspread

# %%
from oauth2client.service_account import ServiceAccountCredentials
scope =["https://spreadsheets.google.com/feeds",'https://www.googleapis.com/auth/spreadsheets',"https://www.googleapis.com/auth/drive.file","https://www.googleapis.com/auth/drive"]
creds =ServiceAccountCredentials.from_json_keyfile_name("E:/Masai Course(Data Anaytics)/Project/ML project/service_account.json", scope)
client = gspread.authorize(creds)

# %% [markdown]
# ### Import BSE500

# %%
spreadsheet = client.open("BSE500")

# %%
sht1 = client.open_by_url('https://docs.google.com/spreadsheets/d/1-NUgsGhCM1IVTArPg_Lbz5bAKlcv3IRJZa0mTVqI7NI/edit#gid=138566287')

# %%
worksheet_list = sht1.worksheets()

# %%
worksheet = sht1.worksheet("bse500")

# %%
import pandas as pd
BSE = pd.DataFrame(worksheet.get_all_records())

# %%
BSE.head()
# Out:
#                                        Company  BSE code    NSE code  \
# 0                            Sanofi India Ltd.    500674      SANOFI
# 1                         Page Industries Ltd.    532827     PAGEIND
# 2  Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                            Abbott India Ltd.    500488  ABBOTINDIA
# 4                                   Bosch Ltd.    500530    BOSCHLTD
#
#            ISIN            Sector                       Industry        Date  \
# 0  INE058A01010        Healthcare                 Drugs & Pharma  2022-09-05
# 1  INE761H01022          Textiles             Readymade Garments  2022-09-05
# 2  INE179A01014  Consumer Staples  Household & Personal Products  2022-09-05
# 3  INE358A01014        Healthcare                 Drugs & Pharma  2022-09-05
# 4  INE323A01026        Automobile               Auto Ancillaries  2022-09-05
#
#       Price  1 day change(%)  52 Week Low  ...  Price earnings to growth  \
# ...

# %% [markdown]
# ### Import Income_Expense

# %%
spreadsheet2 = client.open("Income_Expense")

# %%
shtt2=client.open_by_url('https://docs.google.com/spreadsheets/d/14F7EnNaiI9QbF9ampaNN_uyreLVIbxk5fASM2Nnuh3k/edit#gid=612640899')

# %%
worksheet_2 = shtt2.worksheet("inex")

# %%
Income_Expense = pd.DataFrame(worksheet_2.get_all_records())

# %%
Income_Expense.head()
# Out:
#              Date               Account        Category Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food
# 1  3/2/2022 10:11  CUB - online payment           Other
# 2  3/1/2022 19:50  CUB - online payment            Food
# 3  3/1/2022 18:56  CUB - online payment  Transportation
# 4  3/1/2022 18:22  CUB - online payment            Food
#
#                Note    INR Income/Expense  Amount Currency
# 0           Brownie   50.0        Expense    50.0      INR
# 1  To lended people  300.0        Expense   300.0      INR
# 2            Dinner   78.0        Expense    78.0      INR
# 3             Metro   30.0        Expense    30.0      INR
# 4            Snacks   67.0        Expense    67.0      INR

# %% [markdown]
# ### Import Final_report - 1

# %%
spreadsheet3 = client.open("Final Report")

# %%
shtt3_1=client.open_by_url('https://docs.google.com/spreadsheets/d/1oVZk2TQ1rh6PVjZNvn_-QX58D_spTXNEZ6dcK6aD2nQ/edit#gid=0')

# %%
worksheet_3 = shtt3_1.worksheet("Sheet1")

# %%
Final_report1 = pd.DataFrame(worksheet_3.get_all_records())

# %%
Final_report1
# Out:
#                   Net Income  THIS NEEDS TO BE FILLED
# 0                Net Expense  THIS NEEDS TO BE FILLED
# 1
# 2                       Food  THIS NEEDS TO BE FILLED
# 3                      Other  THIS NEEDS TO BE FILLED
# 4             Transportation  THIS NEEDS TO BE FILLED
# 5                Social Life  THIS NEEDS TO BE FILLED
# 6                  Household  THIS NEEDS TO BE FILLED
# 7                    Apparel  THIS NEEDS TO BE FILLED
# 8                  Education  THIS NEEDS TO BE FILLED
# 9                     Salary  THIS NEEDS TO BE FILLED
# 10                 Allowance  THIS NEEDS TO BE FILLED
# 11                    Beauty  THIS NEEDS TO BE FILLED
# 12                      Gift  THIS NEEDS TO BE FILLED
# 13                Petty cash  THIS NEEDS TO BE FILLED
# 14
# 15
# 16  Available for investment  THIS NEEDS TO BE FILLED
# 17
# 18
# 19        Investment Profile              Risk Taking
